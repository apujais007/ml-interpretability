# %%
import joblib

X_train = joblib.load('../data/X_train.joblib')
X_test = joblib.load('../data/X_test.joblib')
X = joblib.load('../data/X.joblib')
data = joblib.load('../data/data_bunch.joblib')
xgb_model = joblib.load('../data/xgb_model.joblib')

# %%
# !pip install lime
# Out:
# ...
#   Using cached lime-0.2.0.1-py3-none-any.whl
# ...
#   Using cached scikit_image-0.25.2-cp313-cp313-win_amd64.whl.metadata (14 kB)
# ...
#   Using cached imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# ...
#   Using cached lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# ...
# Using cached scikit_image-0.25.2-cp313-cp313-win_amd64.whl (12.9 MB)
# Using cached imageio-2.37.0-py3-none-any.whl (315 kB)
# Using cached lazy_loader-0.4-py3-none-any.whl (12 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    ---------- ----------------------------- 1/4 [imageio]
#    -------------------- ------------------- 2/4 [scikit-image]
# ...

# %%
import numpy as np
import lime
import lime.lime_tabular

import joblib

X_train = joblib.load('../data/X_train.joblib')
y_train = joblib.load('../data/y_train.joblib')
X_test = joblib.load('../data/X_test.joblib')
X = joblib.load('../data/X.joblib')
data = joblib.load('../data/data_bunch.joblib')
xgb_model = joblib.load('../data/xgb_model.joblib')


explainer = lime.lime_tabular.LimeTabularExplainer(
    training_data=np.array(X_train),
    feature_names=X.columns,
    class_names=data.target_names,
    mode='classification'
)

i = 0  # example index
exp = explainer.explain_instance(X_test.iloc[i].values, xgb_model.predict_proba, num_features=5)
exp.show_in_notebook(show_table=True)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[10], line 12
#      10 X = joblib.load('../data/X.joblib')
#      11 data = joblib.load('../data/data_bunch.joblib')
# ---> 12 xgb_model = joblib.load('../data/xgb_model.joblib')
#      15 explainer = lime.lime_tabular.LimeTabularExplainer(
#      16     training_data=np.array(X_train),
#      17     feature_names=X.columns,
#      18     class_names=data.target_names,
#      19     mode='classification'
#      20 )
#      22 i = 0  # example index
#
# File ~\AppData\Roaming\Python\Python313\site-packages\joblib\numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
# ...
